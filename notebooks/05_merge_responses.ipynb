# %% [markdown]
# <a href="https://colab.research.google.com/github/anushah-200/factcheckAI/blob/main/notebooks/05_merge_responses.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q pandas

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
openai_df = pd.read_csv("/content/drive/MyDrive/factcheckAI/outputs/openai_responses.csv")

groq_df = pd.read_csv("/content/drive/MyDrive/factcheckAI/outputs/groq_responses.csv")

deepseek_df = pd.read_csv("/content/drive/MyDrive/factcheckAI/outputs/deepseek_responses.csv")

# %%
#checking sizes
print(openai_df.shape)

print(groq_df.shape)

print(deepseek_df.shape)
# Out:
# (817, 6)
# (817, 6)
# (817, 6)

# %%
merged = pd.concat([openai_df, groq_df, deepseek_df],ignore_index=True)

# %%
merged.shape
# Out:
# (2451, 6)

# %%
#saving new
merged.to_csv("/content/drive/MyDrive/factcheckAI/outputs/merged_responses.csv",index=False)
